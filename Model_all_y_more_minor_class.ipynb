# %%
import pandas as pd

df = pd.read_excel('Berlin_accidents_clean.xlsx')
df
# Out:
#            id  land  district  year  month  hour  day_of_week  \
# 0      219249    11         3  2021     11    18            2
# 1      219248    11         7  2021     12    19            7
# 2      219247    11         4  2021     12    17            4
# 3      219246    11         4  2021     12    15            7
# 4      219243    11        11  2021     12     9            5
# ...       ...   ...       ...   ...    ...   ...          ...
# 11261  112174    11         4  2021      3    16            4
# 11262  111541    11         4  2021      1     1            6
# 11263  110370    11         3  2021      1    20            1
# 11264  109998    11         7  2021      1    14            7
# 11265  109753    11        12  2021      1    14            2
#
#        accident_category  accident_details  accident_type  light_condition  \
# 0                      3                 0              3                2
# ...

# %%
df100 = pd.read_excel('Berlin_accidents_clean_2018_2021.xlsx')
df100
# Out:
#            id  land  district  year  month  hour  day_of_week  \
# 0      219249    11         3  2021     11    18            2
# 1      219248    11         7  2021     12    19            7
# 2      219247    11         4  2021     12    17            4
# 3      219246    11         4  2021     12    15            7
# 4      219243    11        11  2021     12     9            5
# ...       ...   ...       ...   ...    ...   ...          ...
# 50108  208846    11         4  2018     12    10            6
# 50109  208848    11         3  2018     12    10            6
# 50110  208850    11         2  2018     12     9            6
# 50111  208851    11        11  2018     12     9            6
# 50112  208853    11         7  2018     12     7            6
#
#        accident_category  accident_details  accident_type  light_condition  \
# 0                      3                 0              3                2
# ...

# %%
new_df = df100[df100['year'] != 2021]
new_df
# Out:
#            id  land  district  year  month  hour  day_of_week  \
# 11266    3187    11         8  2020      1    11            4
# 11267    3198    11         4  2020      1     2            3
# 11268    3215    11         4  2020      1     7            1
# 11269    3224    11         2  2020      1    22            6
# 11270    3241    11         4  2020      1    17            1
# ...       ...   ...       ...   ...    ...   ...          ...
# 50108  208846    11         4  2018     12    10            6
# 50109  208848    11         3  2018     12    10            6
# 50110  208850    11         2  2018     12     9            6
# 50111  208851    11        11  2018     12     9            6
# 50112  208853    11         7  2018     12     7            6
#
#        accident_category  accident_details  accident_type  light_condition  \
# 11266                  2                 3              6                0
# ...

# %%
new = new_df[new_df['accident_category'] != 3]
new
# Out:
#            id  land  district  year  month  hour  day_of_week  \
# 11266    3187    11         8  2020      1    11            4
# 11267    3198    11         4  2020      1     2            3
# 11269    3224    11         2  2020      1    22            6
# 11273    3290    11         7  2020      1    15            7
# 11282    3379    11        12  2020      1    14            5
# ...       ...   ...       ...   ...    ...   ...          ...
# 50096  208823    11         8  2018     12    19            7
# 50097  208825    11        11  2018     12    10            7
# 50099  208828    11         1  2018     12     2            7
# 50101  208832    11        11  2018     12    14            6
# 50111  208851    11        11  2018     12     9            6
#
#        accident_category  accident_details  accident_type  light_condition  \
# 11266                  2                 3              6                0
# ...

# %%
more_balanced=pd.concat([df, new],ignore_index=True)
more_balanced
# Out:
#            id  land  district  year  month  hour  day_of_week  \
# 0      219249    11         3  2021     11    18            2
# 1      219248    11         7  2021     12    19            7
# 2      219247    11         4  2021     12    17            4
# 3      219246    11         4  2021     12    15            7
# 4      219243    11        11  2021     12     9            5
# ...       ...   ...       ...   ...    ...   ...          ...
# 17280  208823    11         8  2018     12    19            7
# 17281  208825    11        11  2018     12    10            7
# 17282  208828    11         1  2018     12     2            7
# 17283  208832    11        11  2018     12    14            6
# 17284  208851    11        11  2018     12     9            6
#
#        accident_category  accident_details  accident_type  light_condition  \
# 0                      3                 0              3                2
# ...

# %%
more_balanced.to_excel("More_balanced_data_Berlin_accidents.xlsx", index=False)
