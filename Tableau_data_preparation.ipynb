# %%
import pandas as pd

df = pd.read_excel('Berlin_accidents_clean.xlsx')
df
# Out:
#            id  land  district  year  month  hour  day_of_week  \
# 0      219249    11         3  2021     11    18            2
# 1      219248    11         7  2021     12    19            7
# 2      219247    11         4  2021     12    17            4
# 3      219246    11         4  2021     12    15            7
# 4      219243    11        11  2021     12     9            5
# ...       ...   ...       ...   ...    ...   ...          ...
# 11261  112174    11         4  2021      3    16            4
# 11262  111541    11         4  2021      1     1            6
# 11263  110370    11         3  2021      1    20            1
# 11264  109998    11         7  2021      1    14            7
# 11265  109753    11        12  2021      1    14            2
#
#        accident_category  accident_details  accident_type  light_condition  \
# 0                      3                 0              3                2
# ...

# %%
#Getting Months names
month_names = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June',
               7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

# use the map() method to replace the encoded months with their corresponding month names
df['month'] = df['month'].map(month_names)
df
# Out:
#            id  land  district  year     month  hour  day_of_week  \
# 0      219249    11         3  2021  November    18            2
# 1      219248    11         7  2021  December    19            7
# 2      219247    11         4  2021  December    17            4
# 3      219246    11         4  2021  December    15            7
# 4      219243    11        11  2021  December     9            5
# ...       ...   ...       ...   ...       ...   ...          ...
# 11261  112174    11         4  2021     March    16            4
# 11262  111541    11         4  2021   January     1            6
# 11263  110370    11         3  2021   January    20            1
# 11264  109998    11         7  2021   January    14            7
# 11265  109753    11        12  2021   January    14            2
#
#        accident_category  accident_details  accident_type  light_condition  \
# 0                      3                 0              3                2
# ...

# %%
#Getting district names
district_names = {1: 'Mitte', 2: 'Friedrichshain-Kreuzberg', 3: 'Pankow', 4: 'Charlottenburg-Wilmersdorf', 5: 'Spandau', 6: 'Steglitz-Zehlendorf',
               7: 'Tempelhof-Schöneberg', 8: 'Neukölln', 9: 'Treptow-Köpenick', 10: 'Marzahn-Hellersdorf', 11: 'Lichtenberg', 12: 'Reinickendorf'}

# use the map() method to replace the encoded months with their corresponding month names
df['district'] = df['district'].map(district_names)
df
# Out:
#            id  land                    district  year     month  hour  \
# 0      219249    11                      Pankow  2021  November    18
# 1      219248    11        Tempelhof-Schöneberg  2021  December    19
# 2      219247    11  Charlottenburg-Wilmersdorf  2021  December    17
# 3      219246    11  Charlottenburg-Wilmersdorf  2021  December    15
# 4      219243    11                 Lichtenberg  2021  December     9
# ...       ...   ...                         ...   ...       ...   ...
# 11261  112174    11  Charlottenburg-Wilmersdorf  2021     March    16
# 11262  111541    11  Charlottenburg-Wilmersdorf  2021   January     1
# 11263  110370    11                      Pankow  2021   January    20
# 11264  109998    11        Tempelhof-Schöneberg  2021   January    14
# 11265  109753    11               Reinickendorf  2021   January    14
#
#        day_of_week  accident_category  accident_details  accident_type  \
# ...

# %%
#Getting day of the week
weekday_names = {1: 'Sunday', 2: 'Monday', 3: 'Tuesday', 4: 'Wednesday', 5: 'Thursday', 6: 'Friday',
               7: 'Saturday'}

# use the map() method to replace the encoded months with their corresponding month names
df['day_of_week'] = df['day_of_week'].map(weekday_names)
df
# Out:
#            id  land                    district  year     month  hour  \
# 0      219249    11                      Pankow  2021  November    18
# 1      219248    11        Tempelhof-Schöneberg  2021  December    19
# 2      219247    11  Charlottenburg-Wilmersdorf  2021  December    17
# 3      219246    11  Charlottenburg-Wilmersdorf  2021  December    15
# 4      219243    11                 Lichtenberg  2021  December     9
# ...       ...   ...                         ...   ...       ...   ...
# 11261  112174    11  Charlottenburg-Wilmersdorf  2021     March    16
# 11262  111541    11  Charlottenburg-Wilmersdorf  2021   January     1
# 11263  110370    11                      Pankow  2021   January    20
# 11264  109998    11        Tempelhof-Schöneberg  2021   January    14
# 11265  109753    11               Reinickendorf  2021   January    14
#
#       day_of_week  accident_category  accident_details  accident_type  \
# ...

# %%
#Translating severity
severity = {1: 'fatalities', 2: 'serious injuries', 3: 'minor injuries'}

# use the map() method to replace the encoded months with their corresponding month names
df['accident_category'] = df['accident_category'].map(severity)
df
# Out:
#            id  land                    district  year     month  hour  \
# 0      219249    11                      Pankow  2021  November    18
# 1      219248    11        Tempelhof-Schöneberg  2021  December    19
# 2      219247    11  Charlottenburg-Wilmersdorf  2021  December    17
# 3      219246    11  Charlottenburg-Wilmersdorf  2021  December    15
# 4      219243    11                 Lichtenberg  2021  December     9
# ...       ...   ...                         ...   ...       ...   ...
# 11261  112174    11  Charlottenburg-Wilmersdorf  2021     March    16
# 11262  111541    11  Charlottenburg-Wilmersdorf  2021   January     1
# 11263  110370    11                      Pankow  2021   January    20
# 11264  109998    11        Tempelhof-Schöneberg  2021   January    14
# 11265  109753    11               Reinickendorf  2021   January    14
#
#       day_of_week accident_category  accident_details  accident_type  \
# ...

# %%
#Translating day light
light = {0: 'daylight', 1: 'twilight', 2: 'darkness'}

# use the map() method to replace the encoded months with their corresponding month names
df['light_condition'] = df['light_condition'].map(light)
df
# Out:
#            id  land                    district  year     month  hour  \
# 0      219249    11                      Pankow  2021  November    18
# 1      219248    11        Tempelhof-Schöneberg  2021  December    19
# 2      219247    11  Charlottenburg-Wilmersdorf  2021  December    17
# 3      219246    11  Charlottenburg-Wilmersdorf  2021  December    15
# 4      219243    11                 Lichtenberg  2021  December     9
# ...       ...   ...                         ...   ...       ...   ...
# 11261  112174    11  Charlottenburg-Wilmersdorf  2021     March    16
# 11262  111541    11  Charlottenburg-Wilmersdorf  2021   January     1
# 11263  110370    11                      Pankow  2021   January    20
# 11264  109998    11        Tempelhof-Schöneberg  2021   January    14
# 11265  109753    11               Reinickendorf  2021   January    14
#
#       day_of_week accident_category  accident_details  accident_type  \
# ...

# %%
#Translating road condition
light = {0: 'dry', 1: 'wet/damp/slippery', 2: 'winter slippery'}

# use the map() method to replace the encoded months with their corresponding month names
df['road_condition'] = df['road_condition'].map(light)
df
# Out:
#            id  land                    district  year     month  hour  \
# 0      219249    11                      Pankow  2021  November    18
# 1      219248    11        Tempelhof-Schöneberg  2021  December    19
# 2      219247    11  Charlottenburg-Wilmersdorf  2021  December    17
# 3      219246    11  Charlottenburg-Wilmersdorf  2021  December    15
# 4      219243    11                 Lichtenberg  2021  December     9
# ...       ...   ...                         ...   ...       ...   ...
# 11261  112174    11  Charlottenburg-Wilmersdorf  2021     March    16
# 11262  111541    11  Charlottenburg-Wilmersdorf  2021   January     1
# 11263  110370    11                      Pankow  2021   January    20
# 11264  109998    11        Tempelhof-Schöneberg  2021   January    14
# 11265  109753    11               Reinickendorf  2021   January    14
#
#       day_of_week accident_category  accident_details  accident_type  \
# ...

# %%
df.to_excel("Tableau_Berlin_accidents_2021.xlsx", index=False)

# %%
import pandas as pd

df1 = pd.read_excel('Berlin_accidents_clean_2018_2021.xlsx')
df1
# Out:
#            id  land  district  year  month  hour  day_of_week  \
# 0      219249    11         3  2021     11    18            2
# 1      219248    11         7  2021     12    19            7
# 2      219247    11         4  2021     12    17            4
# 3      219246    11         4  2021     12    15            7
# 4      219243    11        11  2021     12     9            5
# ...       ...   ...       ...   ...    ...   ...          ...
# 50108  208846    11         4  2018     12    10            6
# 50109  208848    11         3  2018     12    10            6
# 50110  208850    11         2  2018     12     9            6
# 50111  208851    11        11  2018     12     9            6
# 50112  208853    11         7  2018     12     7            6
#
#        accident_category  accident_details  accident_type  light_condition  \
# 0                      3                 0              3                2
# ...

# %%
#Getting Months names

month_names = {1: 'January', 2: 'February', 3: 'March', 4: 'April', 5: 'May', 6: 'June',
               7: 'July', 8: 'August', 9: 'September', 10: 'October', 11: 'November', 12: 'December'}

# map() method replaces the encoded months with their corresponding month names
df1['month'] = df1['month'].map(month_names)


#Getting district names
district_names = {1: 'Mitte', 2: 'Friedrichshain-Kreuzberg', 3: 'Pankow', 4: 'Charlottenburg-Wilmersdorf', 5: 'Spandau', 6: 'Steglitz-Zehlendorf',
               7: 'Tempelhof-Schöneberg', 8: 'Neukölln', 9: 'Treptow-Köpenick', 10: 'Marzahn-Hellersdorf', 11: 'Lichtenberg', 12: 'Reinickendorf'}

df1['district'] = df1['district'].map(district_names)

#Getting day of the week
weekday_names = {1: 'Sunday', 2: 'Monday', 3: 'Tuesday', 4: 'Wednesday', 5: 'Thursday', 6: 'Friday',
               7: 'Saturday'}


df1['day_of_week'] = df1['day_of_week'].map(weekday_names)

#Translating severity
severity = {1: 'fatalities', 2: 'serious injuries', 3: 'minor injuries'}


df1['accident_category'] = df1['accident_category'].map(severity)

#Translating day light
light = {0: 'daylight', 1: 'twilight', 2: 'darkness'}


df1['light_condition'] = df1['light_condition'].map(light)

#Translating road condition
light = {0: 'dry', 1: 'wet/damp/slippery', 2: 'winter slippery'}


df1['road_condition'] = df1['road_condition'].map(light)

df1
# Out:
#            id  land                    district  year     month  hour  \
# 0      219249    11                      Pankow  2021  November    18
# 1      219248    11        Tempelhof-Schöneberg  2021  December    19
# 2      219247    11  Charlottenburg-Wilmersdorf  2021  December    17
# 3      219246    11  Charlottenburg-Wilmersdorf  2021  December    15
# 4      219243    11                 Lichtenberg  2021  December     9
# ...       ...   ...                         ...   ...       ...   ...
# 50108  208846    11  Charlottenburg-Wilmersdorf  2018  December    10
# 50109  208848    11                      Pankow  2018  December    10
# 50110  208850    11    Friedrichshain-Kreuzberg  2018  December     9
# 50111  208851    11                 Lichtenberg  2018  December     9
# 50112  208853    11        Tempelhof-Schöneberg  2018  December     7
#
#       day_of_week accident_category  accident_details  accident_type  \
# ...

# %%
df1.to_excel("New_Tableau_Berlin_accidents_2018_2021.xlsx", index=False)
